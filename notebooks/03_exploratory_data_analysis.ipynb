# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# ## Imports

# %%
#Import required modules

import os
import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import matplotlib.dates as mdates

from pathlib import Path

import ppscore as pps

# %% [markdown]
# ## Read Data

# %%
# Change directory one step back and save as the root directory
ROOT_DIR = os.path.normpath(os.getcwd() + os.sep + os.pardir)
print(ROOT_DIR)
# Out:
# D:\gitProjects\springboard_capstone_1\Springboard_Capstone_01

# %%
#Define file name and location
dataset_csv = 'step2_data_wrangling_wti_price.csv'
path = '\\data\\interim\\'
f = ROOT_DIR + path + dataset_csv
print(f)
# Out:
# D:\gitProjects\springboard_capstone_1\Springboard_Capstone_01\data\interim\step2_data_wrangling_wti_price.csv

# %%
df = pd.read_csv(f)

# %%
#convert 'Date' column to date format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors="raise")

#set Date as index
df.set_index('Date', drop=True, inplace=True)

# %% [markdown]
# ## Data explorotary

# %% [markdown]
# ### Check dataframe

# %%
display(df.head(7).round(2).T)
# Out:
# Date                              2000-02-01  2000-03-01  2000-04-01  \
# wti_price                              29.37       29.84       25.72
# oil_production_opec                    26.68       26.61       27.52
# oil_production_nonopec                 46.82       46.94       46.62
# oil_production_world                74470.54    74439.05    75116.13
# henry_hub_ng_price                      2.66        2.79        3.04
# oil_production_us                       5.85        5.92        5.85
# petrol_consumption_oecd                50.23       49.36       46.29
# petrol_consumption_nonoecd             28.77       28.53       28.13
# us_cpi                                  1.70        1.71        1.71
# us_ppi                                  1.30        1.31        1.31
# us_ppi_petroleum                        0.84        0.90        0.85
# us_pmi                                 92.57       93.19       93.81
# crude_oil_inventory_total             896.84      906.89      936.02
# crude_oil_inventory_spr               569.37      569.41      569.41
# crude_oil_inventory_nonspr            285.85      297.09      303.83
# refiner_wholesale_gasoline_price       88.40       98.90       88.50
# refiner_wholesale_diesel_price         85.20       85.10       79.90
# brent_price                            27.78       27.49       22.76
# fed_fund_effective                      5.73        5.85        6.02
# global_real_econ_activity_index        -9.59        5.08        8.16
# us_cpi_energy                          57.52       60.23       59.49
# eu19_ppi                                1.11        1.10        4.17
# usd_eur_exchange                        0.98        0.96        0.94
# global_econ_policy_uncert_index        58.70       61.32       64.55
# comp                                 4410.87     4802.99     3863.64
# copper_futures                          0.80        0.81        0.80
# djia                                10541.93    10483.39    10944.31
# dxy                                   105.92      105.44      110.14
# gold_futures                          295.40      281.40      276.00
# spx                                  1388.87     1442.21     1461.36
#
# Date                              2000-05-01  2000-06-01  2000-07-01  \
# wti_price                              28.79       31.82       29.70
# oil_production_opec                    28.05       27.64       27.91
# oil_production_nonopec                 46.62       46.78       47.05
# oil_production_world                75639.56    75360.22    75983.05
# henry_hub_ng_price                      3.59        4.29        3.99
# oil_production_us                       5.85        5.82        5.74
# petrol_consumption_oecd                47.34       47.96       47.25
# petrol_consumption_nonoecd             28.22       28.27       28.54
# us_cpi                                  1.71        1.72        1.73
# us_ppi                                  1.32        1.32        1.33
# us_ppi_petroleum                        0.88        0.97        0.93
# us_pmi                                 93.88       94.02       94.09
# crude_oil_inventory_total             948.33      957.06      969.28
# crude_oil_inventory_spr               569.41      568.89      570.35
# crude_oil_inventory_nonspr            294.71      290.62      282.19
# refiner_wholesale_gasoline_price       97.90      109.30       99.30
# refiner_wholesale_diesel_price         81.40       82.40       83.60
# brent_price                            27.74       29.80       28.68
# fed_fund_effective                      6.27        6.53        6.54
# global_real_econ_activity_index         4.17        2.93        4.62
# us_cpi_energy                          59.64       63.88       63.92
# eu19_ppi                                1.92        0.68        3.40
# usd_eur_exchange                        0.91        0.95        0.94
# global_econ_policy_uncert_index        87.12       88.40       65.30
# comp                                 3528.42     3866.42     4017.68
# copper_futures                          0.82        0.82        0.88
# djia                                10580.27    10582.93    10662.81
# dxy                                   108.74      106.84      109.57
# gold_futures                          274.80      293.00      280.20
# spx                                  1418.48     1461.96     1473.00
#
# Date                              2000-08-01
# wti_price                              31.26
# oil_production_opec                    28.88
# oil_production_nonopec                 46.93
# oil_production_world                76857.51
# henry_hub_ng_price                      4.43
# oil_production_us                       5.79
# petrol_consumption_oecd                49.83
# petrol_consumption_nonoecd             28.70
# us_cpi                                  1.73
# us_ppi                                  1.34
# us_ppi_petroleum                        0.91
# us_pmi                                 93.50
# crude_oil_inventory_total             960.43
# crude_oil_inventory_spr               571.36
# crude_oil_inventory_nonspr            287.29
# refiner_wholesale_gasoline_price       96.90
# refiner_wholesale_diesel_price         92.10
# brent_price                            30.20
# fed_fund_effective                      6.50
# global_real_econ_activity_index         6.07
# us_cpi_energy                          62.05
# eu19_ppi                                0.82
# usd_eur_exchange                        0.90
# global_econ_policy_uncert_index        54.32
# comp                                 3909.60
# copper_futures                          0.89
# djia                                11014.51
# dxy                                   112.60
# gold_futures                          280.80
# spx                                  1485.46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 269 entries, 2000-02-01 to 2022-06-01
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   wti_price                         269 non-null    float64
#  1   oil_production_opec               269 non-null    float64
#  2   oil_production_nonopec            269 non-null    float64
#  3   oil_production_world              269 non-null    float64
#  4   henry_hub_ng_price                269 non-null    float64
#  5   oil_production_us                 269 non-null    float64
#  6   petrol_consumption_oecd           269 non-null    float64
#  7   petrol_consumption_nonoecd        269 non-null    float64
#  8   us_cpi                            269 non-null    float64
#  9   us_ppi                            269 non-null    float64
#  10  us_ppi_petroleum                  269 non-null    float64
#  11  us_pmi                            269 non-null    float64
#  12  crude_oil_inventory_total         269 non-null    float64
#  13  crude_oil_inventory_spr           269 non-null    float64
#  14  crude_oil_inventory_nonspr        269 non-null    float64
#  15  refiner_wholesale_gasoline_price  269 non-null    float64
#  16  refiner_wholesale_diesel_price    269 non-null    float64
#  17  brent_price                       269 non-null    float64
#  18  fed_fund_effective                269 non-null    float64
#  19  global_real_econ_activity_index   269 non-null    float64
#  20  us_cpi_energy                     269 non-null    float64
#  21  eu19_ppi                          269 non-null    float64
#  22  usd_eur_exchange                  269 non-null    float64
#  23  global_econ_policy_uncert_index   269 non-null    float64
#  24  comp                              269 non-null    float64
#  25  copper_futures                    269 non-null    float64
#  26  djia                              269 non-null    float64
#  27  dxy                               269 non-null    float64
#  28  gold_futures                      269 non-null    float64
#  29  spx                               269 non-null    float64
# dtypes: float64(30)
# memory usage: 65.1 KB

# %% [markdown]
# ### Traget feature

# %%
#Plot the target feature
fig, ax = plt.subplots(figsize = (16,7))
sns.lineplot(data = df, x = df.index, y = 'wti_price')

# assign locator and formatter for the xaxis ticks.
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# put the labels at 45deg since they tend to be too long
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ### Histograms

# %%
#Plot histogram of all  features
#Call plt.subplots_adjust() with an argument hspace=0.5 to adjust the spacing
#It's important you create legible and easy-to-read plots
df.hist(figsize=(15,15))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# ### Summary Statistics

# %%
display(df.describe().round(2).T)
# Out:
#                                   count      mean      std       min  \
# wti_price                         269.0     62.05    25.99     16.55
# oil_production_opec               269.0     29.03     1.96     22.35
# oil_production_nonopec            269.0     55.65     5.91     46.62
# oil_production_world              269.0  87089.82  7226.03  73916.41
# henry_hub_ng_price                269.0      4.47     2.16      1.63
# oil_production_us                 269.0      7.45     2.49      3.97
# petrol_consumption_oecd           269.0     47.49     2.32     35.02
# petrol_consumption_nonoecd        269.0     42.05     8.35     28.13
# us_cpi                            269.0      2.22     0.30      1.70
# us_ppi                            269.0      1.81     0.30      1.29
# us_ppi_petroleum                  269.0      1.95     0.78      0.59
# us_pmi                            269.0     97.12     4.89     80.40
# crude_oil_inventory_total         269.0   1107.18   141.39    861.21
# crude_oil_inventory_spr           269.0    662.03    52.84    493.32
# crude_oil_inventory_nonspr        269.0    363.70    74.69    268.39
# refiner_wholesale_gasoline_price  269.0    188.33    71.61     58.30
# refiner_wholesale_diesel_price    269.0    192.79    82.36     54.60
# brent_price                       269.0     64.90    29.54     18.38
# fed_fund_effective                269.0      1.60     1.86      0.05
# global_real_econ_activity_index   269.0      9.11    71.04   -163.16
# us_cpi_energy                     269.0     98.30    21.64     54.71
# eu19_ppi                          269.0      0.54     2.75     -9.07
# usd_eur_exchange                  269.0      1.20     0.16      0.85
# global_econ_policy_uncert_index   269.0    139.83    71.69     48.88
# comp                              269.0   4466.39  3433.63   1241.89
# copper_futures                    269.0      2.58     1.13      0.63
# djia                              269.0  15951.71  7400.13   7235.47
# dxy                               269.0     91.11    11.25     71.80
# gold_futures                      269.0   1038.47   515.76    259.20
# spx                               269.0   1829.07   927.69    757.13
#
#                                        25%       50%       75%       max
# wti_price                            40.94     59.04     81.89    133.88
# oil_production_opec                  28.18     29.29     30.45     32.39
# oil_production_nonopec               50.89     54.34     60.71     67.46
# oil_production_world              82720.84  85934.43  94237.58  99859.49
# henry_hub_ng_price                    2.87      3.91      5.61     13.42
# oil_production_us                     5.45      5.88      9.38     13.00
# petrol_consumption_oecd              46.21     47.45     48.96     52.88
# petrol_consumption_nonoecd           34.28     42.93     50.02     54.63
# us_cpi                                1.98      2.24      2.42      2.95
# us_ppi                                1.60      1.88      2.01      2.76
# us_ppi_petroleum                      1.33      1.91      2.46      4.67
# us_pmi                               93.64     98.87    100.29    106.47
# crude_oil_inventory_total           999.22   1062.97   1236.87   1457.70
# crude_oil_inventory_spr             637.77    688.15    695.95    726.62
# crude_oil_inventory_nonspr          306.04    336.95    429.13    538.60
# refiner_wholesale_gasoline_price    133.60    182.00    235.80    412.34
# refiner_wholesale_diesel_price      127.50    188.60    245.40    434.79
# brent_price                          42.69     62.34     82.66    132.72
# fed_fund_effective                    0.13      1.00      2.28      6.54
# global_real_econ_activity_index     -43.80      3.27     53.81    188.06
# us_cpi_energy                        86.07    101.17    112.92    168.03
# eu19_ppi                             -0.86      0.32      1.62     16.89
# usd_eur_exchange                      1.11      1.20      1.32      1.58
# global_econ_policy_uncert_index      88.40    120.42    170.87    430.26
# comp                               2143.53   2850.35   5260.57  15814.93
# copper_futures                        1.54      2.80      3.40      4.75
# djia                              10500.95  12656.63  18697.33  35848.57
# dxy                                  81.54     90.27     97.35    120.24
# gold_futures                        468.80   1182.30   1386.10   1974.50
# spx                                1181.41   1418.48   2177.48   4674.77

# %% [markdown]
# ### Correlation matrix

# %%
def plot_corr_matrix (df, round_val, mask = False):
    '''This function plots Correlation matrix'''
    
    # Compute the correlation matrix
    corr = df.corr()
    
    #Plot Corr matrix
    
    # Generate a mask for the upper triangle
    if mask:
        mask = np.triu(np.ones_like(corr, dtype=bool))
    
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(30, 15))

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr.round(round_val), mask=mask, cmap='coolwarm', vmin = -1, vmax=1, center=0, annot=True,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}).set(title='Pearson Correlation Matrix')

    plt.show()

# %%
plot_corr_matrix(df, 1, True)

# %% [markdown]
# ### PPS: Predictive Power Score

# %%
def plot_pps_matrix(df, round_val, mask = False):
    '''This function gets a df and plot PPS score matrix'''
    
    # Compute the PPS matrix
    matrix = pps.matrix(df)

    #Plot PPS
    matrix_pps = matrix[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')

    # Generate a mask for the upper triangle
    if mask:
        mask = np.triu(np.ones_like(matrix_pps, dtype=bool))

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(30, 15))

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(matrix_pps.round(round_val), mask = mask, cmap="Blues", vmin = 0, vmax=1, center=0.5,
                square=True, linewidths=.5,annot=True, cbar_kws={"shrink": .5}).set(title='PPS Matrix')
    plt.show()

# %%
plot_pps_matrix(df, 1, True)

# %% [markdown]
# ### Scatter Plots

# %%
def plot_scatterplots(data, columns, target_feature, ncol=None, figsize=(15, 8)):
    '''This function creates scatterplots of crude oil prices against desired columns'''
    
    if ncol is None:
        ncol = len(columns)
        
    nrow = int(np.ceil(len(columns) / ncol))
    
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=1)
    
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = target_feature, data=data, alpha=0.5)
        ax.set(xlabel=col, ylabel= target_feature)
        
    nsubplots = nrow * ncol
    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
#define features to be plotted against WTI price
features = [item for item in df.columns if item not in ['wti_price']]

# %%
plot_scatterplots(df, features, 'wti_price',  ncol=4, figsize=(15, 20))

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Add price spread features

# %%
# Calcualte additional features.
df['wti_brent_price_spread'] = df['wti_price'] - df['brent_price']
df['wti_crack_spread'] = 2*df['refiner_wholesale_gasoline_price'] + df['refiner_wholesale_diesel_price'] - 3*df['wti_price']
df['brent_crack_spread'] = 2*df['refiner_wholesale_gasoline_price'] + df['refiner_wholesale_diesel_price'] - 3*df['brent_price']

# Drop unnecessary columns
df = df.drop(columns=['brent_price', 'refiner_wholesale_gasoline_price', 'refiner_wholesale_diesel_price'])

# %% [markdown]
# ### Score assosciation with target feature

# %%
def count_over_thershold(li, bounding_limit: tuple):
    '''This function gets a list and print how many items are larger than a thersold'''
    
    #counters
    n = len(li)
    m = 0    
    for i in li:
        if i >= bounding_limit[1] or i < bounding_limit[0] :
            m +=1
    pct = 100.0*m/n
    print(f'{pct:1.2f}% of items ({m}/{n}) are out of {bounding_limit}')

# %%
def highlight_out_of_range(data, bounding_limit: tuple):
    '''This functions gets PPS score for target feature and plot a bar plot'''
    lower_bound = bounding_limit[0]
    upper_bound = bounding_limit[1]
    
    #Plot the scores for a select feature from PPS Matrix
    data= data.sort_values(ascending = False)

    #The value > thershold will be show with a different color.
    #So, the plot colors will be dynamically set based on the data

    #Create and empty list of colors
    colors = []

    #Set color for ratio values
    #Set "red" if value is max, otherwise "blue" (as default)
    for index, value in data.items():
        if value >= upper_bound or value <= lower_bound:
            colors.append('#f77088') #red for max
        else:
            colors.append('#66aabb') #blue as default

    #set chart size
    fig = plt.figure(figsize = (15, 2))


    #Pass the x and height values with color set to bar plotter
    plt.bar(data.index,data.values, width = .8, color=colors)

    #Rotate the x labels for better visuzlaizarion
    plt.xticks(rotation=90)

    #Set labels
    plt.ylabel('PPS score')
    
    
    count_over_thershold(data, bounding_limit)

    #Show the plot
    plt.show()

# %%
def target_pps_score(df, feature):
    # Compute the PPS matrix
    matrix = pps.matrix(df)
    matrix_pps = matrix[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
    y_scores = matrix_pps[feature]
    
    return y_scores

# %%
def target_corr_coeff(df, feature):
    
    # Compute the correlation matrix
    corr = df.corr()
    y_scores = corr[feature]
    
    return y_scores

# %% [markdown]
# ### High PPS Score

# %%
wti_pps_score = target_pps_score(df, 'wti_price')

# %%
highlight_out_of_range(wti_pps_score, (0,0.6))
# Out:
# 10.00% of items (3/30) are out of (0, 0.6)

# %% [markdown]
# ### High Correlation Coeff

# %%
wti_corr_coeff = target_corr_coeff(df, 'wti_price')

# %%
highlight_out_of_range(wti_corr_coeff, (-0.6,0.6))
# Out:
# 30.00% of items (9/30) are out of (-0.6, 0.6)

# %% [markdown]
# ## Store the data

# %%
# Change directory one step back and save as the root directory
ROOT_DIR = os.path.normpath(os.getcwd() + os.sep + os.pardir)

# Change direcotry to the 'data\raw' folder
path = ROOT_DIR + '\\data\\interim\\'

# Set a file name
file_save = path + 'step3_eda_wti_price.csv'
df.to_csv(file_save)

print('Save:\n', file_save)
# Out:
# Save:
#  D:\gitProjects\springboard_capstone_1\Springboard_Capstone_01\data\interim\step3_eda_wti_price.csv
