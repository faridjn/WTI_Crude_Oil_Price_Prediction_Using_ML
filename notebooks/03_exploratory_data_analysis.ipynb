# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# ## Imports

# %%
#Import required modules

import os
import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import matplotlib.dates as mdates

from pathlib import Path

import ppscore as pps

# %% [markdown]
# ## Custom Functions

# %%
def count_over_thershold(li, bounding_limit: tuple):
    '''This function gets a list and print how many items are larger than a thersold'''
    
    #counters
    n = len(li)
    m = 0    
    for i in li:
        if i >= bounding_limit[1] or i < bounding_limit[0] :
            m +=1
    pct = 100.0*m/n
    print(f'{pct:1.2f}% of items ({m}/{n}) are out of {bounding_limit}')

# %%
def plot_corr_matrix (df, mask = False):
    '''This function plots Correlation matrix'''
    
    # Compute the correlation matrix
    corr = df.corr()
    
    #Plot Corr matrix
    
    # Generate a mask for the upper triangle
    if mask:
        mask = np.triu(np.ones_like(corr, dtype=bool))
    
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(10, 10))

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap='coolwarm', vmin = -1, vmax=1, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}).set(title='Pearson Correlation Matrix')

    plt.show()

# %%
def plot_pps_matrix(df, mask = False):
    '''This function gets a df and plot PPS score matrix'''
    
    # Compute the PPS matrix
    matrix = pps.matrix(df)

    #Plot PPS
    matrix_pps = matrix[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')

    # Generate a mask for the upper triangle
    if mask:
        mask = np.triu(np.ones_like(matrix_pps, dtype=bool))

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(10, 10))

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(matrix_pps, mask = mask, cmap="Blues", vmin = 0, vmax=1, center=0.5,
                square=True, linewidths=.5,annot=False, cbar_kws={"shrink": .5}).set(title='PPS Matrix')
    plt.show()

# %%
def highlight_out_of_range(data, bounding_limit: tuple):
    '''This functions gets PPS score for target feature and plot a bar plot'''
    lower_bound = bounding_limit[0]
    upper_bound = bounding_limit[1]
    
    #Plot the scores for a select feature from PPS Matrix
    data= data.sort_values(ascending = False)

    #The value > thershold will be show with a different color.
    #So, the plot colors will be dynamically set based on the data

    #Create and empty list of colors
    colors = []

    #Set color for ratio values
    #Set "red" if value is max, otherwise "blue" (as default)
    for index, value in data.items():
        if value >= upper_bound or value <= lower_bound:
            colors.append('#f77088') #red for max
        else:
            colors.append('#66aabb') #blue as default

    #set chart size
    fig = plt.figure(figsize = (15, 2))


    #Pass the x and height values with color set to bar plotter
    plt.bar(data.index,data.values, width = .8, color=colors)

    #Rotate the x labels for better visuzlaizarion
    plt.xticks(rotation=90)

    #Set labels
    plt.ylabel('PPS score')
    
    
    count_over_thershold(data, bounding_limit)

    #Show the plot
    plt.show()

# %%
def target_pps_score(df, feature):
    # Compute the PPS matrix
    matrix = pps.matrix(df)
    matrix_pps = matrix[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
    y_scores = matrix_pps[feature]
    
    return y_scores

# %%
def target_corr_coeff(df, feature):
    
    # Compute the correlation matrix
    corr = df.corr()
    y_scores = corr[feature]
    
    return y_scores

# %%
# define useful function to create scatterplots of crude oil prices against desired columns
def plot_scatterplots(data, columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
        
    nrow = int(np.ceil(len(columns) / ncol))
    
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=1)
    
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = 'WTI_Price', data=data, alpha=0.5)
        ax.set(xlabel=col, ylabel='WTI_Price')
        
    nsubplots = nrow * ncol
    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %% [markdown]
# ## Read Data

# %%
# Change directory one step back and save as the root directory
ROOT_DIR = os.path.normpath(os.getcwd() + os.sep + os.pardir)
print(ROOT_DIR)
# Out:
# D:\gitProjects\springboard_capstone_1\Springboard_Capstone_01

# %%
#Define file name and location
dataset_csv = 'merged_eia_fred_offile.csv'
path = '\\data\\interim\\'
f = ROOT_DIR + path + dataset_csv
print(f)
# Out:
# D:\gitProjects\springboard_capstone_1\Springboard_Capstone_01\data\interim\merged_eia_fred_offile.csv

# %%
df = pd.read_csv(f)

# %%
#convert 'Date' column to date format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors="raise")

#set Date as index
df.set_index('Date', drop=True, inplace=True)

# %% [markdown]
# ## Data explorotary

# %% [markdown]
# ### Check dataframe

# %%
display(df.head().T)
# Out:
# Date                                    2000-02-01    2000-03-01  \
# WTI_Price                                29.366000     29.842000
# Oil_Production_OPEC                      26.675516     26.608782
# Oil_Production_nonOPEC                   46.822508     46.937266
# Oil_Production_World                  74470.542507  74439.049968
# Henry_Hub_NG_Price                        2.660000      2.790000
# Oil_Production_US                         5.851839      5.918207
# Petrol_Consumption_OECD                  50.229341     49.358083
# Petrol_Consumption_nonOECD               28.770679     28.528547
# US_CPI                                    1.700000      1.710000
# US_PPI                                    1.299187      1.305372
# US_PPI_Petroleum                          0.840000      0.897000
# US_PMI                                   92.566900     93.194900
# Crude_Oil_Inventory_Total               896.840000    906.889002
# Crude_Oil_Inventory_SPR                 569.370000    569.413000
# Crude_Oil_Inventory_nonSPR              285.847000    297.087000
# Refiner_Wholesale_Gasoline_Price         88.400000     98.900000
# Refiner_Wholesale_Diesel_Price           85.200000     85.100000
# Brent_Price                              27.775000     27.486000
# Fed_Fund_Effective                        5.730000      5.850000
# Index_Global_Real_Econ_Activity          -9.591177      5.080761
# US_CPI_Energy                            57.517435     60.228197
# EU19_PPI                                  1.113173      1.100917
# USD_EUR_Exchange                          0.983400      0.964300
# Global_Econ_Policy_Uncertainty_Index     58.702252     61.315905
# COMP                                   4410.871000   4802.988261
# Copper_Futures                            0.798000      0.808500
# DJIA                                  10541.929500  10483.390435
# DXY                                     105.920000    105.440000
# Gold_Futures                            295.400000    281.400000
# SPX                                    1388.874000   1442.213043
#
# Date                                    2000-04-01    2000-05-01    2000-06-01
# WTI_Price                                25.722000     28.788000     31.822000
# Oil_Production_OPEC                      27.516678     28.048591     27.639380
# Oil_Production_nonOPEC                   46.618731     46.623961     46.778141
# Oil_Production_World                  75116.129376  75639.562523  75360.217843
# Henry_Hub_NG_Price                        3.040000      3.590000      4.290000
# Oil_Production_US                         5.854166      5.846510      5.822882
# Petrol_Consumption_OECD                  46.286749     47.338795     47.955820
# Petrol_Consumption_nonOECD               28.131882     28.216862     28.270995
# US_CPI                                    1.709000      1.712000      1.722000
# US_PPI                                    1.311693      1.317793      1.323801
# US_PPI_Petroleum                          0.846000      0.876000      0.974000
# US_PMI                                   93.805100     93.881500     94.015900
# Crude_Oil_Inventory_Total               936.018999    948.328000    957.061001
# Crude_Oil_Inventory_SPR                 569.413000    569.413000    568.893000
# Crude_Oil_Inventory_nonSPR              303.833000    294.712000    290.623000
# Refiner_Wholesale_Gasoline_Price         88.500000     97.900000    109.300000
# Refiner_Wholesale_Diesel_Price           79.900000     81.400000     82.400000
# Brent_Price                              22.764000     27.737000     29.795000
# Fed_Fund_Effective                        6.020000      6.270000      6.530000
# Index_Global_Real_Econ_Activity           8.161007      4.170149      2.934744
# US_CPI_Energy                            59.488898     59.636758     63.875404
# EU19_PPI                                  4.174229      1.916376      0.683761
# USD_EUR_Exchange                          0.944900      0.905900      0.950500
# Global_Econ_Policy_Uncertainty_Index     64.554036     87.116240     88.401506
# COMP                                   3863.637368   3528.416818   3866.422273
# Copper_Futures                            0.796000      0.816000      0.824000
# DJIA                                  10944.310526  10580.267727  10582.925909
# DXY                                     110.140000    108.740000    106.840000
# Gold_Futures                            276.000000    274.800000    293.000000
# SPX                                    1461.355263   1418.479545   1461.959091

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 269 entries, 2000-02-01 to 2022-06-01
# Data columns (total 30 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   WTI_Price                             269 non-null    float64
#  1   Oil_Production_OPEC                   269 non-null    float64
#  2   Oil_Production_nonOPEC                269 non-null    float64
#  3   Oil_Production_World                  269 non-null    float64
#  4   Henry_Hub_NG_Price                    269 non-null    float64
#  5   Oil_Production_US                     269 non-null    float64
#  6   Petrol_Consumption_OECD               269 non-null    float64
#  7   Petrol_Consumption_nonOECD            269 non-null    float64
#  8   US_CPI                                269 non-null    float64
#  9   US_PPI                                269 non-null    float64
#  10  US_PPI_Petroleum                      269 non-null    float64
#  11  US_PMI                                269 non-null    float64
#  12  Crude_Oil_Inventory_Total             269 non-null    float64
#  13  Crude_Oil_Inventory_SPR               269 non-null    float64
#  14  Crude_Oil_Inventory_nonSPR            269 non-null    float64
#  15  Refiner_Wholesale_Gasoline_Price      269 non-null    float64
#  16  Refiner_Wholesale_Diesel_Price        269 non-null    float64
#  17  Brent_Price                           269 non-null    float64
#  18  Fed_Fund_Effective                    269 non-null    float64
#  19  Index_Global_Real_Econ_Activity       269 non-null    float64
#  20  US_CPI_Energy                         269 non-null    float64
#  21  EU19_PPI                              269 non-null    float64
#  22  USD_EUR_Exchange                      269 non-null    float64
#  23  Global_Econ_Policy_Uncertainty_Index  269 non-null    float64
#  24  COMP                                  269 non-null    float64
#  25  Copper_Futures                        269 non-null    float64
#  26  DJIA                                  269 non-null    float64
#  27  DXY                                   269 non-null    float64
#  28  Gold_Futures                          269 non-null    float64
#  29  SPX                                   269 non-null    float64
# dtypes: float64(30)
# memory usage: 65.1 KB

# %% [markdown]
# ### Traget feature

# %%
#Plot the target feature
fig, ax = plt.subplots(figsize = (16,7))
sns.lineplot(data = df, x = df.index, y = 'WTI_Price')

# assign locator and formatter for the xaxis ticks.
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# put the labels at 45deg since they tend to be too long
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ### Histograms

# %%
#Plot histogram of all  features
#Call plt.subplots_adjust() with an argument hspace=0.5 to adjust the spacing
#It's important you create legible and easy-to-read plots
df.hist(figsize=(15,15))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# ### Correlation matrix

# %%
plot_corr_matrix(df, False)

# %% [markdown]
# ### PPS: Predictive Power Score

# %%
plot_pps_matrix(df, False)

# %% [markdown]
# ### Scatter Plots

# %%
#define features to be plotted against WTI price
features = [item for item in df.columns if item not in ['WTI_Price']]

# %%
plot_scatterplots(df, features, ncol=4, figsize=(15, 20))

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Add price spread features

# %%
# Calcualte additioanl features.
df['WTI_Brent_Price_Spread'] = df['WTI_Price'] - df['Brent_Price']
df['WTI_Crack_Spread'] = 2*df['Refiner_Wholesale_Gasoline_Price'] + df['Refiner_Wholesale_Diesel_Price'] - 3*df['WTI_Price']
df['Brent_Crack_Spread'] = 2*df['Refiner_Wholesale_Gasoline_Price'] + df['Refiner_Wholesale_Diesel_Price'] - 3*df['Brent_Price']

# Drop unnecessary columns
df = df.drop(columns=['Brent_Price', 'Refiner_Wholesale_Gasoline_Price', 'Refiner_Wholesale_Diesel_Price'])

# %% [markdown]
# ### Look for PPS score assosciation with target feature

# %%
wti_pps_score = target_pps_score(df, 'WTI_Price')

# %%
highlight_out_of_range(wti_pps_score, (0,0.6))

# %% [markdown]
# ### Look for correlation coeff

# %%
wti_corr_coeff = target_corr_coeff(df, 'WTI_Price')

# %%
highlight_out_of_range(wti_corr_coeff, (-0.6,0.6))

# %% [markdown]
# ## Store the data

# %%
# Change directory one step back and save as the root directory
ROOT_DIR = os.path.normpath(os.getcwd() + os.sep + os.pardir)

# Change direcotry to the 'data\raw' folder
path = ROOT_DIR + '\\data\\interim\\'

# Set a file name
file_save = path + 'crude_oil_price_step3_features.csv'
df.to_csv(file_save)

print('Save:\n', file_save)
